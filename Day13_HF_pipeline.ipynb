# %% [markdown]
# <a href="https://colab.research.google.com/github/exp-deepthy/my-angular/blob/master/Day13_HF_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq transformers

# %% [markdown]
# # Understanding Pipeline
#
# * Pre-Processing
# * Model
# * Post-Processing

# %%
from transformers import pipeline

pipe = pipeline("text-classification")
pipe(["This restaurant is awesome", "This restaurant is aweful"])
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998743534088135},
#  {'label': 'POSITIVE', 'score': 0.9996858835220337}]

# %%
classifier = pipeline("zero-shot-classification")
classifier("This is course is about the Transformers Library",
           candidate_labels=["education", "politics", "business"])
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'sequence': 'This is course is about the Transformers Library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.7117041349411011, 0.19015935063362122, 0.09813651442527771]}

# %% [markdown]
# # Understanding Transfer Learning
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Understanding Transformers
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Vision pipeline
#
# [reference](https://github.com/NielsRogge/Transformers-Tutorials/blob/master/HuggingFace_vision_ecosystem_overview_(June_2022).ipynb)

# %%
from PIL import Image

url = '/content/great-hornbill.jpg'
image = Image.open(r'/content/great-hornbill.jpg')
image

# %%
from transformers import pipeline

image_pipe = pipeline("image-classification")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 5dca96d (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
image_pipe(image)

# %% [markdown]
# # Using Gradio
